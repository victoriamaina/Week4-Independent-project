# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriamaina/Week4-Independent-project/blob/main/VictoriaMainaWk4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#Loading the datasets to be used in the analysis
autolib_df=pd.read_csv('/content/Autolib_dataset (2).csv')
autolib_df
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
#read first 10 rows
#
autolib_df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
# 5                8 Boulevard Voltaire     0                0  ...    6     7       2
# 6                      37 rue Leblanc     0                0  ...    8    18      20
# 7         17 Rue des Luaps Prolong̩e     3                3  ...    4    22      13
# 8               34 avenue Jean Moulin     1                1  ...    2    22      58
# 9        41 boulevard de Rochechouart     6                6  ...    4    15       2
#
# [10 rows x 25 columns]

# %%
#read last 10 rows
#
autolib_df.tail()
# Out:
#                           Address  Cars  Bluecar counter  ...  day  hour  minute
# 4995          8 avenue M̩nelotte     2                2  ...    6    11      26
# 4996            37 rue de Dantzig     4                4  ...    4    16      56
# 4997               142 rue du Bac     1                1  ...    1     7       1
# 4998  2 avenue du Val de Fontenay     2                2  ...    4    17      27
# 4999          5 Rue Henry Brisson     4                4  ...    8    10       2
#
# [5 rows x 25 columns]

# %%
#data understanding 
#data 4info ,missing values,duplicates etc
#
autolib_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
autolib_df.describe()
# Out:
#               Cars  Bluecar counter  ...         hour       minute
# count  5000.000000      5000.000000  ...  5000.000000  5000.000000
# mean      2.333600         2.333600  ...    11.509200    29.270000
# std       2.035274         2.035274  ...     6.893549    17.231741
# min       0.000000         0.000000  ...     0.000000     0.000000
# 25%       0.000000         0.000000  ...     6.000000    14.000000
# 50%       2.000000         2.000000  ...    11.000000    29.000000
# 75%       4.000000         4.000000  ...    18.000000    44.000000
# max       7.000000         7.000000  ...    23.000000    59.000000
#
# [8 rows x 12 columns]

# %%
#count missing values
#
np.count_nonzero(autolib_df.isnull())
# Out:
# 9842

# %%
#merging year, month and day as date.
autolib_df['dateint'] =autolib_df['year'].astype(str) + autolib_df['month'].astype(str).str.zfill(2) + autolib_df['day'].astype(str).str.zfill(2)
autolib_df['date']=pd.to_datetime(autolib_df['dateint'])
autolib_df
# Out:
#                                  Address  Cars  ...   dateint       date
# 0                    2 Avenue de Suffren     0  ...  20180408 2018-04-08
# 1              145 Rue Raymond Losserand     6  ...  20180406 2018-04-06
# 2       2 Avenue John Fitzgerald Kennedy     3  ...  20180403 2018-04-03
# 3                 51 Rue Eug̬ne Oudin̩     3  ...  20180404 2018-04-04
# 4     6 avenue de la Porte de Champerret     3  ...  20180408 2018-04-08
# ...                                  ...   ...  ...       ...        ...
# 4995                 8 avenue M̩nelotte     2  ...  20180406 2018-04-06
# 4996                   37 rue de Dantzig     4  ...  20180404 2018-04-04
# 4997                      142 rue du Bac     1  ...  20180401 2018-04-01
# 4998         2 avenue du Val de Fontenay     2  ...  20180404 2018-04-04
# 4999                 5 Rue Henry Brisson     4  ...  20180408 2018-04-08
#
# [5000 rows x 27 columns]

# %%
# dropping the columns that are not reqiured
autolib_df=autolib_df.drop(['month','year','day','dateint',], axis= 1)

# %%
#drop column car coz its redudant to blue car
#
autolib_df=autolib_df.drop(['Cars'], axis= 1)

# %%
autolib_df
# Out:
#                                  Address  Bluecar counter  ...  minute       date
# 0                    2 Avenue de Suffren                0  ...      43 2018-04-08
# 1              145 Rue Raymond Losserand                6  ...      24 2018-04-06
# 2       2 Avenue John Fitzgerald Kennedy                3  ...      14 2018-04-03
# 3                 51 Rue Eug̬ne Oudin̩                3  ...      37 2018-04-04
# 4     6 avenue de la Porte de Champerret                3  ...      23 2018-04-08
# ...                                  ...              ...  ...     ...        ...
# 4995                 8 avenue M̩nelotte                2  ...      26 2018-04-06
# 4996                   37 rue de Dantzig                4  ...      56 2018-04-04
# 4997                      142 rue du Bac                1  ...       1 2018-04-01
# 4998         2 avenue du Val de Fontenay                2  ...      27 2018-04-04
# ...

# %% [markdown]
# DATA ANALYSIS

# %%
#Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
pop_pick_bluecar=autolib_df[(autolib_df["City"]=='Paris')& (autolib_df['date']>='2018-04-01') & (autolib_df['date']<='2018-04-30') ]
pop_pick_bluecar1=pd.pivot_table(Paris,values=[('Bluecar counter')],index=['hour'],aggfunc=np.sum)
pop_pick_bluecar1
pop_pick_bluecar1.sort_values(by='Bluecar counter',ascending=0).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-cbd15c13295e> in <module>()
#       1 #Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
#       2 pop_pick_bluecar=autolib_df[(autolib_df["City"]=='Paris')& (autolib_df['date']>='2018-04-01') & (autolib_df['date']<='2018-04-30') ]
# ----> 3 pop_pick_bluecar1=pd.pivot_table(Paris,values=[('Bluecar counter')],index=['hour'],aggfunc=np.sum)
#       4 pop_pick_bluecar1
#       5 pop_pick_bluecar1.sort_values(by='Bluecar counter',ascending=0).head(10)
#
# NameError: name 'Paris' is not defined

# %%
#Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
pop_pick_bluecar=autolib_df[(autolib_df["City"]=='Paris')& (autolib_df['date']>='2018-04-01') & (autolib_df['date']<='2018-04-30') ]
pop_pick_bluecar1=pd.pivot_table(paris,values=[('Bluecar counter')],index=['hour'])
pop_pick_bluecar1
pop_pick_bluecar1.sort_values(by='Bluecar counter',ascending=0).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5c1122c9304f> in <module>()
#       1 #Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
#       2 pop_pick_bluecar=autolib_df[(autolib_df["City"]=='Paris')& (autolib_df['date']>='2018-04-01') & (autolib_df['date']<='2018-04-30') ]
# ----> 3 pop_pick_bluecar1=pd.pivot_table(paris,values=[('Bluecar counter')],index=['hour'])
#       4 pop_pick_bluecar1
#       5 pop_pick_bluecar1.sort_values(by='Bluecar counter',ascending=0).head(10)
#
# NameError: name 'paris' is not defined

# %%
#What is the most popular hour for returning cars?
#
popular_return_carhour = pd.pivot_table(autolib_df,values=['Slots'],index=['hour'],aggfunc=np.sum)
popular_return_carhour.sort_values(by='Slots',ascending=0).head(3)
# Out:
#       Slots
# hour
# 14      441
# 2       440
# 21      438

# %%
#What is the most popular hour for returning cars?
#
popular_return_carhour = pd.pivot_table(autolib_df,values=['Slots'],index=['hour'])
popular_return_carhour.sort_values(by='Slots',ascending=0).head(3)
# Out:
#          Slots
# hour
# 23    2.154229
# 14    2.130435
# 15    2.075000

# %%
#creeating a new column and getting the sum of the 3 types of cars: bluecar_counter,utilib_counter,utilib_1.4_counter
autolib_df['Car_Total']= autolib_df.iloc[:, 0:4].sum(axis=1)

# %%
autolib_df.head()
# Out:
#                               Address  Bluecar counter  ...       date  Car_Total
# 0                 2 Avenue de Suffren                0  ... 2018-04-08          0
# 1           145 Rue Raymond Losserand                6  ... 2018-04-06          6
# 2    2 Avenue John Fitzgerald Kennedy                3  ... 2018-04-03          5
# 3              51 Rue Eug̬ne Oudin̩                3  ... 2018-04-04          4
# 4  6 avenue de la Porte de Champerret                3  ... 2018-04-08          3
#
# [5 rows x 23 columns]

# %%
#What station is the most popular?
autolib_df.groupby(['ID','Postal code'])['Car_Total'].sum().sort_values(ascending = False).head()
# Out:
# ID                                   Postal code
# paris-portedemontrouge-8             75014          50
# fontenayauxroses-robertmarchand-32   92260          50
# leplessisrobinson-galilee-16         92350          49
# fontenayauxroses-lombard-20          92260          48
# fontenayauxroses-divisionleclerc-31  92260          46
# Name: Car_Total, dtype: int64

# %%
autolib_df.groupby(['ID','Postal code'])['Car_Total'].sum().sort_values(ascending = False).head().plot(kind = 'bar')

# %%
#What postal code is the most popular for picking up Blue cars? Does the most popular station belong to that postal code?
autolib_df.groupby(['Postal code','hour'])['Bluecar counter'].sum().sort_values(ascending = False).head()
# Out:
# Postal code  hour
# 75015        6       44
# 75017        23      43
# 92000        7       43
#              13      42
# 75016        1       41
# Name: Bluecar counter, dtype: int64

# %%
autolib_df.groupby(['Postal code','hour'])['Bluecar counter'].sum().sort_values(ascending = False).head().plot(kind = 'bar')

# %%
#At the most popular picking hour?
autolib_df.groupby(['Postal code','hour'])['Bluecar counter'].sum().sort_values(ascending = False).head()
# Out:
# Postal code  hour
# 75015        6       44
# 75017        23      43
# 92000        7       43
#              13      42
# 75016        1       41
# Name: Bluecar counter, dtype: int64

# %%
#Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars? 
autolib_df.groupby(['ID','Postal code','hour'])['Utilib counter'].sum().sort_values(ascending = False).head()
# Out:
# ID                                     Postal code  hour
# paris-jeanjacquesrousseau-62           75001        14      2
# paris-arago-99                         75014        21      2
# paris-hericart-54                      75015        8       2
# fontenaysousbois-jeanpierretimbaud-17  94120        0       2
# paris-chateaubriand-19                 75008        18      2
# Name: Utilib counter, dtype: int64
